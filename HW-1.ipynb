# %% [markdown]
# # Машинное обучение и майнинг данных
# ## Домашнее задание №1 -  Основы Pandas

# %% [markdown]
# <center> Шестаков Андрей* </center>
#
#
# Материал распространяется на условиях лицензии <a href="https://opensource.org/licenses/MS-RL">Ms-RL</a>. Можно использовать в любых целях, кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
#  <font color="white">* Настоящий автор материала</font>

# %% [markdown]
# <hr\>
# **Общая информация**
#
# **Срок сдачи:** 17 ноября 2016, 23:59 <br\>
# **Штраф за опоздание:** -1 за каждый день
#
# При отправлении ДЗ указывайте фамилию в названии файла<br\>
#
# Сопровождайте ваш код изображеними, комментариями и выводами. <br\>
# Иммейте ввиду, что на некоторые задачи нет единственного верного и полного ответа. Чем больше информации вы сможете извлечь, аргументированных выводов сформулировать, тем лучше.
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.
# <hr\>

# %%
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ### Воздушные перевозки
#
# Скачайте следующий [архив](http://stat-computing.org/dataexpo/2009/2008.csv.bz2). Описание полей таблицы дано [здесь](http://www.transtats.bts.gov/Fields.asp?Table_ID=236).
#
# Данные должны содержать перелеты воздушных судов в 2008 году (вероятно в США). Архив можно не распаковывать, Pandas умеет налету разархивировать данные.
#
# Если в вашем компьютере не хватает оперативной памяти, то в функции `.read_csv` используйте параметр `nrows=N` - в этом случае вы загрузите только `N` первых строк.

# %%
df = pd.read_csv('2008.csv.bz2', compression='bz2')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 29 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtypes: float64(14), int64(10), object(5)
# memory usage: 1.5+ GB

# %% [markdown]
# #### Общие характеристики таблицы

# %% [markdown]
# Укажите количество строк и стобцов в данных. <br/>
# Выведите первые 10 строк таблицы и общие описательные статистики по столбцам.

# %%
df.shape
# Out:
# (7009728, 29)

# %%
df.head(10).T
# Out:
#                         0       1       2       3       4       5       6  \
# Year                 2008    2008    2008    2008    2008    2008    2008
# Month                   1       1       1       1       1       1       1
# DayofMonth              3       3       3       3       3       3       3
# DayOfWeek               4       4       4       4       4       4       4
# DepTime              2003     754     628     926    1829    1940    1937
# CRSDepTime           1955     735     620     930    1755    1915    1830
# ArrTime              2211    1002     804    1054    1959    2121    2037
# CRSArrTime           2225    1000     750    1100    1925    2110    1940
# UniqueCarrier          WN      WN      WN      WN      WN      WN      WN
# FlightNum             335    3231     448    1746    3920     378     509
# TailNum            N712SW  N772SW  N428WN  N612SW  N464WN  N726SW  N763SW
# ActualElapsedTime     128     128      96      88      90     101     240
# CRSElapsedTime        150     145      90      90      90     115     250
# AirTime               116     113      76      78      77      87     230
# ArrDelay              -14       2      14      -6      34      11      57
# DepDelay                8      19       8      -4      34      25      67
# Origin                IAD     IAD     IND     IND     IND     IND     IND
# Dest                  TPA     TPA     BWI     BWI     BWI     JAX     LAS
# Distance              810     810     515     515     515     688    1591
# TaxiIn                  4       5       3       3       3       4       3
# TaxiOut                 8      10      17       7      10      10       7
# Cancelled               0       0       0       0       0       0       0
# CancellationCode      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# Diverted                0       0       0       0       0       0       0
# CarrierDelay          NaN     NaN     NaN     NaN       2     NaN      10
# WeatherDelay          NaN     NaN     NaN     NaN       0     NaN       0
# NASDelay              NaN     NaN     NaN     NaN       0     NaN       0
# SecurityDelay         NaN     NaN     NaN     NaN       0     NaN       0
# LateAircraftDelay     NaN     NaN     NaN     NaN      32     NaN      47
#
#                         7       8       9
# Year                 2008    2008    2008
# Month                   1       1       1
# DayofMonth              3       3       3
# DayOfWeek               4       4       4
# DepTime              1039     617    1620
# CRSDepTime           1040     615    1620
# ArrTime              1132     652    1639
# CRSArrTime           1150     650    1655
# UniqueCarrier          WN      WN      WN
# FlightNum             535      11     810
# TailNum            N428WN  N689SW  N648SW
# ActualElapsedTime     233      95      79
# CRSElapsedTime        250      95      95
# AirTime               219      70      70
# ArrDelay              -18       2     -16
# DepDelay               -1       2       0
# Origin                IND     IND     IND
# Dest                  LAS     MCI     MCI
# Distance             1591     451     451
# TaxiIn                  7       6       3
# TaxiOut                 7      19       6
# Cancelled               0       0       0
# CancellationCode      NaN     NaN     NaN
# Diverted                0       0       0
# CarrierDelay          NaN     NaN     NaN
# WeatherDelay          NaN     NaN     NaN
# NASDelay              NaN     NaN     NaN
# SecurityDelay         NaN     NaN     NaN
# LateAircraftDelay     NaN     NaN     NaN

# %%
df.describe(include="all").T
# Out:
# /Users/georgesemenov/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                          count unique     top     freq        mean        std  \
# Year               7.00973e+06    NaN     NaN      NaN        2008          0
# Month              7.00973e+06    NaN     NaN      NaN     6.37513    3.40674
# DayofMonth         7.00973e+06    NaN     NaN      NaN      15.728    8.79707
# DayOfWeek          7.00973e+06    NaN     NaN      NaN     3.92418    1.98826
# DepTime            6.87348e+06    NaN     NaN      NaN     1333.83    478.069
# CRSDepTime         7.00973e+06    NaN     NaN      NaN     1326.09    464.251
# ArrTime            6.85808e+06    NaN     NaN      NaN     1481.26    505.225
# CRSArrTime         7.00973e+06    NaN     NaN      NaN      1494.8    482.673
# UniqueCarrier          7009728     20      WN  1201754         NaN        NaN
# FlightNum          7.00973e+06    NaN     NaN      NaN      2224.2    1961.72
# TailNum                6926363   5373  N476HA     4701         NaN        NaN
# ActualElapsedTime  6.85503e+06    NaN     NaN      NaN     127.322    70.1873
# CRSElapsedTime     7.00888e+06    NaN     NaN      NaN     128.867    69.4097
# AirTime            6.85503e+06    NaN     NaN      NaN     104.019    67.4398
# ArrDelay           6.85503e+06    NaN     NaN      NaN     8.16845    38.5019
# DepDelay           6.87348e+06    NaN     NaN      NaN     9.97257    35.3113
# Origin                 7009728    303     ATL   414513         NaN        NaN
# Dest                   7009728    304     ATL   414521         NaN        NaN
# Distance           7.00973e+06    NaN     NaN      NaN     726.387    562.102
# TaxiIn             6.85808e+06    NaN     NaN      NaN     6.86085    4.93365
# TaxiOut            6.87267e+06    NaN     NaN      NaN      16.453    11.3328
# Cancelled          7.00973e+06    NaN     NaN      NaN   0.0196062   0.138643
# CancellationCode        137434      4       B    54904         NaN        NaN
# Diverted           7.00973e+06    NaN     NaN      NaN  0.00246301  0.0495675
# CarrierDelay       1.52474e+06    NaN     NaN      NaN     15.7721    40.0991
# WeatherDelay       1.52474e+06    NaN     NaN      NaN     3.03903    19.5029
# NASDelay           1.52474e+06    NaN     NaN      NaN     17.1646     31.895
# SecurityDelay      1.52474e+06    NaN     NaN      NaN   0.0749743    1.83794
# LateAircraftDelay  1.52474e+06    NaN     NaN      NaN      20.771    39.2596
#
#                     min   25%   50%   75%   max
# Year               2008  2008  2008  2008  2008
# Month                 1     3     6     9    12
# DayofMonth            1     8    16    23    31
# DayOfWeek             1     2     4     6     7
# DepTime               1   NaN   NaN   NaN  2400
# CRSDepTime            0   925  1320  1715  2359
# ArrTime               1   NaN   NaN   NaN  2400
# CRSArrTime            0  1115  1517  1907  2400
# UniqueCarrier       NaN   NaN   NaN   NaN   NaN
# FlightNum             1   622  1571  3518  9743
# TailNum             NaN   NaN   NaN   NaN   NaN
# ActualElapsedTime    12   NaN   NaN   NaN  1379
# CRSElapsedTime     -141   NaN   NaN   NaN  1435
# AirTime               0   NaN   NaN   NaN  1350
# ArrDelay           -519   NaN   NaN   NaN  2461
# DepDelay           -534   NaN   NaN   NaN  2467
# Origin              NaN   NaN   NaN   NaN   NaN
# Dest                NaN   NaN   NaN   NaN   NaN
# Distance             11   325   581   954  4962
# TaxiIn                0   NaN   NaN   NaN   308
# TaxiOut               0   NaN   NaN   NaN   429
# Cancelled             0     0     0     0     1
# CancellationCode    NaN   NaN   NaN   NaN   NaN
# Diverted              0     0     0     0     1
# CarrierDelay          0   NaN   NaN   NaN  2436
# WeatherDelay          0   NaN   NaN   NaN  1352
# NASDelay              0   NaN   NaN   NaN  1357
# SecurityDelay         0   NaN   NaN   NaN   392
# LateAircraftDelay     0   NaN   NaN   NaN  1316

# %% [markdown]
# Напишите, сколько значений пропущено в поле `CarrierDelay`.

# %%
df.CarrierDelay.isnull().sum()
# Out:
# 5484993

# %% [markdown]
# #### Вывод "самых-самых"числовых значений.

# %% [markdown]
# Иногда требуется определить первые n самых больших (маленьких) значений в массиве. По большому счету, для этого надо сначала отсортировать массив, а потом вывести значения на краях массива.
#
# Это может занять много времени. Поэтому в pandas есть метод `.nlargest` `(.nlowest)`. Мы можем даже сравнить их скорость с простой сортировкой

# %%
# При сортировке
# %time df.AirTime.sort_values(ascending=False).head(5)
# Out:
# CPU times: user 1.53 s, sys: 223 ms, total: 1.75 s
# Wall time: 1.86 s
# 2763487    1350.0
# 2763603    1154.0
# 5180146    1091.0
# 2763567     981.0
# 2160490     886.0
# Name: AirTime, dtype: float64

# %% [markdown]
# % - знаменует выполнение magic команд в Ipython notebook. %time, например, измеряет время выполненя строки кода, с которой она начинается. Чтобы замерить время выполнения всей ячейки достаточно в самом начале написать %%time и с новой строки писать остальные команды.
#
# Теперь запустите вариант c `.nlargest()`

# %%
# %%time 
df.AirTime.nlargest(5)
# Out:
# CPU times: user 150 ms, sys: 57.7 ms, total: 208 ms
# Wall time: 233 ms
# 2763487    1350.0
# 2763603    1154.0
# 5180146    1091.0
# 2763567     981.0
# 2160490     886.0
# Name: AirTime, dtype: float64

# %% [markdown]
# #### Частоты для категориальных значений

# %% [markdown]
# С помощью метода `.value_counts()` можно посчитать частоты соответствующих значений. А с помощью метода `.nunique()` - количество уникальных категорий.

# %% [markdown]
# Рассчитайте количество уникальных перевозчиков (UniqueCarrier) и топ-10 самых частовстречаемых перевозчиков.

# %%
df.UniqueCarrier.nunique()
# Out:
# 20

# %%
df.UniqueCarrier.value_counts().head(10)
# Out:
# WN    1201754
# AA     604885
# OO     567159
# MQ     490693
# US     453589
# DL     451931
# UA     449515
# XE     374510
# NW     347652
# CO     298455
# Name: UniqueCarrier, dtype: int64

# %% [markdown]
# Построить распределение причин отмены рейсов (CancellationCode). Используйте метод `.plot(kind='bar')` чтобы изобразить распределение.

# %%
vc = df.CancellationCode.value_counts()
print(vc)
# Out:
# B    54904
# A    54330
# C    28188
# D       12
# Name: CancellationCode, dtype: int64

# %%
vc.plot(kind='bar')

# %% [markdown]
# #### Таблица совместного распределения

# %% [markdown]
# C помощью метода `pd.crosstab(series1, series2)` можно строить таблицы совместного распределения двух (на самом деле даже больше чем двух) категориальных признаков. Выполните эту команду для признаков "день недели" и "месяц"

# %%
pd.crosstab(df.DayOfWeek, df.Month)
# Out:
# Month          1       2       3       4       5       6       7       8   \
# DayOfWeek
# 1           80807   81504  103210   82463   80626  104168   84095   82983
# 2           97298   79700   81159  100785   79884   82160  103429   80895
# 3          100080   80587   82307  102586   81264   82902  103315   81773
# 4          102043   82158   82831   82799  102572   83617  105035   82625
# 5           81940  102726   82936   82964  102878   83930   79349  103878
# 6           67178   66462   86153   68304   84493   72322   72219   86155
# 7           76419   76099   97494   78225   74576   99566   80489   93970
#
# Month         9      10     11     12
# DayOfWeek
# 1          94300  75131  74214  92700
# 2          91533  72195  72443  90568
# 3          74057  91900  73653  85241
# 4          75589  94123  68071  70761
# 5          75881  93894  70484  74306
# 6          58343  58168  76031  61708
# 7          71205  70794  88376  69674

# %% [markdown]
# #### Работа со строковыми значениями
# Если значения в ячейках признака состоят из строк, то с ними можно работать ровно тем же образом, как и с простыми строками в python. Напримет знак + будет склеивать две строки.
#
# Найдите самый популярный маршрут (для этого склейте строки Origin и Dest) и выведите основные статистики по данному маршруту.

# %%
tr = df.Origin + df.Dest
pt = tr.value_counts().index[0]
print(pt)
df[(tr == pt)].describe(include="all").T
# Out:
# SFOLAX
# /Users/georgesemenov/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                    count unique     top   freq        mean        std   min  \
# Year               13788    NaN     NaN    NaN        2008          0  2008
# Month              13788    NaN     NaN    NaN     6.33732    3.35815     1
# DayofMonth         13788    NaN     NaN    NaN     15.7304    8.79138     1
# DayOfWeek          13788    NaN     NaN    NaN       3.863    1.97387     1
# DepTime            13299    NaN     NaN    NaN     1371.03    489.328     3
# CRSDepTime         13788    NaN     NaN    NaN      1356.6    472.941   540
# ArrTime            13286    NaN     NaN    NaN     1481.38     502.01     1
# CRSArrTime         13788    NaN     NaN    NaN     1493.55    473.466     5
# UniqueCarrier      13788      6      UA   5845         NaN        NaN   NaN
# FlightNum          13788    NaN     NaN    NaN     1862.83    1999.17     4
# TailNum            13335   1268  N13908    152         NaN        NaN   NaN
# ActualElapsedTime  13285    NaN     NaN    NaN     82.4178    10.1842    58
# CRSElapsedTime     13788    NaN     NaN    NaN     85.6598    4.57173    39
# AirTime            13285    NaN     NaN    NaN     55.2306    3.65313     3
# ArrDelay           13285    NaN     NaN    NaN     9.43726    38.1609   -37
# DepDelay           13299    NaN     NaN    NaN     12.7124    36.5412   -21
# Origin             13788      1     SFO  13788         NaN        NaN   NaN
# Dest               13788      1     LAX  13788         NaN        NaN   NaN
# Distance           13788    NaN     NaN    NaN         337          0   337
# TaxiIn             13286    NaN     NaN    NaN     9.91216    5.12037     1
# TaxiOut            13299    NaN     NaN    NaN     17.2736    7.12681     4
# Cancelled          13788    NaN     NaN    NaN   0.0354656    0.18496     0
# CancellationCode     489      3       A    368         NaN        NaN   NaN
# Diverted           13788    NaN     NaN    NaN  0.00101538  0.0318499     0
# CarrierDelay        3142    NaN     NaN    NaN     9.68969    27.9592     0
# WeatherDelay        3142    NaN     NaN    NaN     0.36028    8.21601     0
# NASDelay            3142    NaN     NaN    NaN     7.63081    16.6853     0
# SecurityDelay       3142    NaN     NaN    NaN   0.0264163    1.00916     0
# LateAircraftDelay   3142    NaN     NaN    NaN     42.1572    46.7747     0
#
#                     25%   50%   75%   max
# Year               2008  2008  2008  2008
# Month                 3     6     9    12
# DayofMonth            8    16    23    31
# DayOfWeek             2     4     5     7
# DepTime             NaN   NaN   NaN  2400
# CRSDepTime          945  1315  1756  2240
# ArrTime             NaN   NaN   NaN  2400
# CRSArrTime         1110  1443  1920  2359
# UniqueCarrier       NaN   NaN   NaN   NaN
# FlightNum           817  1153  1957  7815
# TailNum             NaN   NaN   NaN   NaN
# ActualElapsedTime   NaN   NaN   NaN   196
# CRSElapsedTime       83    85    88    99
# AirTime             NaN   NaN   NaN    92
# ArrDelay            NaN   NaN   NaN   480
# DepDelay            NaN   NaN   NaN   410
# Origin              NaN   NaN   NaN   NaN
# Dest                NaN   NaN   NaN   NaN
# Distance            337   337   337   337
# TaxiIn              NaN   NaN   NaN   106
# TaxiOut             NaN   NaN   NaN    84
# Cancelled             0     0     0     1
# CancellationCode    NaN   NaN   NaN   NaN
# Diverted              0     0     0     1
# CarrierDelay        NaN   NaN   NaN   339
# WeatherDelay        NaN   NaN   NaN   406
# NASDelay            NaN   NaN   NaN   401
# SecurityDelay       NaN   NaN   NaN    54
# LateAircraftDelay   NaN   NaN   NaN   373

# %% [markdown]
# #### Сводные таблицы
# В pandas достаточно просто строить сводные таблицы. Ниже приводится пример сводной таблицы, в которой приводится количество, среднее и медианное значение времени задержки и доля отмененных рейсов по каждому перевозчику.

# %%
df.groupby('UniqueCarrier')\
  .agg({'CarrierDelay': ['mean', 'median', 'count'],
        'Cancelled': ['mean']})\
  .head(10)
# Out:
#               CarrierDelay                Cancelled
#                       mean median   count      mean
# UniqueCarrier
# 9E               19.864633    0.0   45735  0.027078
# AA               17.309764    0.0  163024  0.028832
# AQ               22.149746   16.0     394  0.005385
# AS               15.960020    0.0   30190  0.014156
# B6               13.766349    0.0   49223  0.016344
# CO               13.637261    0.0   73047  0.012404
# DL               14.277823    0.0   98840  0.015075
# EV               25.375898    7.0   66558  0.017913
# F9               12.708679    3.0   19748  0.003164
# FL                7.660308    0.0   57923  0.008545

# %% [markdown]
# По группам так же можно итерировать. Для каждого перевозчика найтите топ-2 рейса с самой большой CarrierDelay.

# %%
for index, group in df.groupby('UniqueCarrier'):
    CDtop = group.CarrierDelay.nlargest(2)
    print("\n" + index)
    print(CDtop)
    
    #print(group.iloc[CDtop.index[:]])
# Out:
# 9E
# 4092707    1127.0
# 466968     1094.0
# Name: CarrierDelay, dtype: float64
#
# AA
# 1097934    1312.0
# 4757792    1286.0
# Name: CarrierDelay, dtype: float64
#
# AQ
# 1105522    338.0
# 533161     315.0
# Name: CarrierDelay, dtype: float64
#
# AS
# 1723108    947.0
# 6949107    810.0
# Name: CarrierDelay, dtype: float64
#
# B6
# 2341916    834.0
# 1132736    626.0
# Name: CarrierDelay, dtype: float64
#
# CO
# 1141523    1001.0
# 6983389     905.0
# Name: CarrierDelay, dtype: float64
#
# DL
# 6747672    1003.0
# 2695340     863.0
# Name: CarrierDelay, dtype: float64
#
# EV
# 922782    940.0
# 336747    856.0
# Name: CarrierDelay, dtype: float64
#
# F9
# 5154678    809.0
# 3967988    761.0
# Name: CarrierDelay, dtype: float64
#
# FL
# 3984823    1175.0
# 3358723     687.0
# Name: CarrierDelay, dtype: float64
#
# HA
# 5180146    1040.0
# 2763487    1034.0
# Name: CarrierDelay, dtype: float64
#
# MQ
# 3387883    1707.0
# 996512     1351.0
# Name: CarrierDelay, dtype: float64
#
# NW
# 2235378    2436.0
# 2832617    1951.0
# Name: CarrierDelay, dtype: float64
#
# OH
# 1338118    955.0
# 3771572    720.0
# Name: CarrierDelay, dtype: float64
#
# OO
# 1380734    990.0
# 3190102    763.0
# Name: CarrierDelay, dtype: float64
#
# UA
# 4474816    1045.0
# 219451     1032.0
# Name: CarrierDelay, dtype: float64
#
# US
# 3264263    749.0
# 1454339    689.0
# Name: CarrierDelay, dtype: float64
#
# WN
# 6508075    668.0
# 6507957    659.0
# Name: CarrierDelay, dtype: float64
#
# XE
# 709364     838.0
# 1899172    776.0
# Name: CarrierDelay, dtype: float64
#
# YV
# 1309751    606.0
# 5514160    560.0
# Name: CarrierDelay, dtype: float64

# %% [markdown]
# #### Распределение по времени
# Определите, как распределено количество рейсов от времени дня и года

# %%
# Your code here..

# %% [markdown]
# #### Временные ряды

# %%
# Немного магии
df['Date'] = pd.to_datetime(df.Year*10000 + 
                            df.Month*100 + 
                            df.DayofMonth, 
                            format='%Y%m%d')

# %% [markdown]
# С помощью метода groupby составьте временной ряд "количество рейсов в день"

# %%
ts = df.groupby('Date')['FlightNum'].agg('count')
ts
# Out:
# Date
# 2008-01-01    19187
# 2008-01-02    20954
# 2008-01-03    20937
# 2008-01-04    20929
# 2008-01-05    18069
# 2008-01-06    19897
# 2008-01-07    20347
# 2008-01-08    19604
# 2008-01-09    19820
# 2008-01-10    20305
# 2008-01-11    20349
# 2008-01-12    16572
# 2008-01-13    18947
# 2008-01-14    20178
# 2008-01-15    19504
# 2008-01-16    19768
# 2008-01-17    20277
# 2008-01-18    20348
# 2008-01-19    16255
# 2008-01-20    18653
# 2008-01-21    20133
# 2008-01-22    19505
# 2008-01-23    19771
# 2008-01-24    20258
# 2008-01-25    20314
# 2008-01-26    16282
# 2008-01-27    18922
# 2008-01-28    20149
# 2008-01-29    19498
# 2008-01-30    19767
#               ...
# 2008-12-02    18166
# 2008-12-03    18019
# 2008-12-04    18350
# 2008-12-05    18405
# 2008-12-06    14440
# 2008-12-07    17116
# 2008-12-08    18301
# 2008-12-09    17600
# 2008-12-10    17917
# 2008-12-11    18377
# 2008-12-12    18433
# 2008-12-13    14459
# 2008-12-14    17137
# 2008-12-15    18317
# 2008-12-16    17631
# 2008-12-17    18294
# 2008-12-18    18746
# 2008-12-19    18828
# 2008-12-20    16216
# 2008-12-21    17725
# 2008-12-22    18665
# 2008-12-23    18633
# 2008-12-24    15263
# 2008-12-25    15288
# 2008-12-26    18640
# 2008-12-27    16593
# 2008-12-28    17696
# 2008-12-29    18540
# 2008-12-30    18538
# 2008-12-31    15748
# Name: FlightNum, dtype: int64

# %% [markdown]
# С помощью метода `.plot` изобразите временной ряд

# %%
ts.plot()

# %% [markdown]
# Изучите документацию метода `.rolling` и изобразите скользящее среднее данного ряда

# %%
ts.rolling(7).mean().plot()

# %% [markdown]
# #### Scatter plot

# %% [markdown]
# Посчитайте корреляцию между опозданиями вылета и прилета

# %%
# Your code here..
df[['ArrDelay', 'DepDelay']].corr()
# Out:
#           ArrDelay  DepDelay
# ArrDelay  1.000000  0.931391
# DepDelay  0.931391  1.000000

# %% [markdown]
# Возьмите случайным образом (с помощью метода `sample`) выберите 20% из выборки и постройте scatter plot этих двух признаков.

# %%
df.sample(frac = 0.2).plot.scatter(x='ArrDelay', y='DepDelay')
